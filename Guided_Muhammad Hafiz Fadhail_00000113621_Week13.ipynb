# %% [markdown]
# ## <div align="center"> TUGAS LAB IS388 Data Analysis </div>
# ## <div align="center"> WEEK [13]: [Evaluation and Deployment]</div>
# #### <div align="center"> Semester Ganjil 2025/2026 </div>
# ---

# %%
import datetime
import uuid

studentName = "Muhammad Hafiz Fadhail"
studentNIM = "00000113621"
studentClass = "AL"

# %%
myDate = datetime.datetime.now()
myDevice = str(uuid.uuid1())

print("Name: \t\t{}".format(studentName))
print("NIM: \t\t{}".format(studentNIM))
print("NIM: \t\t{}".format(studentClass))
print("Start: \t\t{}".format(myDate))
print("Device ID: \t{}".format(myDevice))
# Out:
# Name: 		Muhammad Hafiz Fadhail
# NIM: 		00000113621
# NIM: 		AL
# Start: 		2025-12-02 18:37:24.782511
# Device ID: 	45ce5e25-cf73-11f0-9dab-80d02c733376

# %% [markdown]
# ---

# %% [markdown]
# ## <div align="center"> Guided Lab </div>

# %% [markdown]
# ### Enter Guided Lab Code Here:

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None)
iris.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Split the data into features and labels

# %%
X = iris.drop('class', axis=1)
y = iris['class']

# %%
y.tail()
# Out:
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: class, dtype: object

# %% [markdown]
# ## Split into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %% [markdown]
# ## Create and train the model

# %%
model = KNeighborsClassifier()
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## Make predictions

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ## Evaluate the model

# %%
accuracy = accuracy_score(y_test, predictions)
print(f'Model Accuracy: {accuracy}')
# Out:
# Model Accuracy: 0.9833333333333333

# %%
import pickle

# %%
# Simpan model ke file
with open('modelKNN1.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
import joblib
# save the model to disk
joblib.dump(model, "knn_model.sav")
# Out:
# ['knn_model.sav']

# %% [markdown]
# ## model.py

# %% [markdown]
# ### Creating the Streamlit UI

# %% [markdown]
# Install Streamlit

# %%
# !pip install streamlit

# %% [markdown]
# ## Go to the "app.py" file and import the Streamlit library

# %%
# Out:
# 2025-12-02 18:37:40.393 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 18:37:41.992
# ...
#   command:
#
#     streamlit run C:\Users\Acer\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-12-02 18:37:41.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 18:37:41.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 18:37:42.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 18:37:42.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 18:37:42.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# Out:
# joblib: 1.4.2
# streamlit: 1.45.1
# scikit-learn: 1.6.1
# pandas: 2.2.3

# %% [markdown]
# ----

# %% [markdown]
# ## <div align="center"> Conclusion </div>

# %% [markdown]
# ### Enter Your Conclusion Here:

# %% [markdown]
# Ini tuh panduan praktis dan menyeluruh mengenai alur kerja machine learning menggunakan dataset Iris, dimulai dari pengolahan data hingga model tersebut siap digunakan. Kita dipandu untuk melatih model klasifikasi, mengukur seberapa tepat prediksinya, serta menyimpannya ke dalam file agar bisa dipakai kembali tanpa harus melatih ulang dari awal. Puncaknya, materi ini menjelaskan cara mengubah model tersebut menjadi aplikasi web sederhana menggunakan Streamlit dan menghubungkannya dengan GitHub, sehingga hasil prediksi kita dapat diakses secara online dan bermanfaat bagi pengguna nyata.

# %% [markdown]
# ----

# %%
studentName2 = "Muhammad Hafiz Fadhail"
studentNIM2 = "00000113621"
studentClass2 = "AL"

# %%
print("Name: \t\t{}".format(studentName2))
print("NIM: \t\t{}".format(studentNIM2))
print("NIM: \t\t{}".format(studentClass2))
print("End: \t\t{}".format(myDate))
print("Device ID: \t{}".format(myDevice))
# Out:
# Name: 		Muhammad Hafiz Fadhail
# NIM: 		00000113621
# NIM: 		AL
# End: 		2025-12-02 18:37:24.782511
# Device ID: 	45ce5e25-cf73-11f0-9dab-80d02c733376

# %% [markdown]
# ----

# %% [markdown]
# ## <div align="center"> Reference </div>

# %% [markdown]
# ### Input Your Reference Here  (Jika ada):

# %% [markdown]
# ----
